# %% [markdown]
# <a href="https://colab.research.google.com/github/yucellgereklioglu/datasciencework/blob/main/Datathon_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import Sequential
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
eğitimverisi=pd.read_csv("/content/eğitimdata.csv")
testverisi=pd.read_csv("/content/test_x.csv")
# Out:
# <ipython-input-8-6c20675fd22d>:1: DtypeWarning: Columns (13,15,19,30,32,37,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   eğitimverisi=pd.read_csv("/content/eğitimdata.csv")

# %% [markdown]
# AMAÇ EĞİTİM VERİSİ SETİNDEN YOLA ÇIKILARAK TEST VERİSİ DEĞERLENDİRME PUANI TAHMİN EDİLMEK İSTENMEKTEDİR.

# %%
eğitimverisi.tail()
# Out:
#        Basvuru Yili  Degerlendirme Puani Cinsiyet      Dogum Tarihi  \
# 65120          2022                  0.0    Erkek  18.06.2003 00:00
# 65121          2022                  0.0    Erkek  18.04.2002 00:00
# 65122          2022                  0.0    Erkek  23.10.1999 00:00
# 65123          2022                  0.0    Erkek  17.11.2000 00:00
# 65124          2022                  NaN    Kadın  27.04.2000 00:00
#
#       Dogum Yeri Ikametgah Sehri                   Universite Adi  \
# 65120   İstanbul        İstanbul      İstanbul Aydın Üniversitesi
# 65121      Hatay           Muğla  Muğla Sıtkı Koçman Üniversitesi
# 65122     Mersin          Mersin    Süleyman Demirel Üniversitesi
# 65123     Samsun          Samsun             Karabük Üniversitesi
# 65124      Hatay           Hatay           Gaziantep Üniversitesi
#
#       Universite Turu  Burslu ise Burs Yuzdesi Burs Aliyor mu?  ...  \
# 65120            Özel                      NaN            Evet  ...
# ...

# %%
le=LabelEncoder()
eğitimverisi["Degerlendirme Puani"]=le.fit_transform(eğitimverisi["Degerlendirme Puani"])
eğitimverisi["Burslu ise Burs Yuzdesi"]=le.fit_transform(eğitimverisi["Burslu ise Burs Yuzdesi"])
eğitimverisi["Cinsiyet"]=le.fit_transform(eğitimverisi["Cinsiyet"])
eğitimverisi["Stk Projesine Katildiniz Mi?"]=le.fit_transform(eğitimverisi["Stk Projesine Katildiniz Mi?"])
eğitimverisi["Ingilizce Seviyeniz?"]=le.fit_transform(eğitimverisi["Ingilizce Seviyeniz?"])

# %%
eğitimverisi.head(2)
# Out:
#    Basvuru Yili  Degerlendirme Puani  Cinsiyet Dogum Tarihi Dogum Yeri  \
# 0          2014                   52         2        10182        114
# 1          2014                   30         2        11028       2027
#
#   Ikametgah Sehri Universite Adi Universite Turu  Burslu ise Burs Yuzdesi  \
# 0              28            438               3                       50
# 1             309            438               3                       50
#
#   Burs Aliyor mu?  ... Spor Dalindaki Rolunuz Nedir?  \
# 0            Evet  ...                         Diğer
# 1           Hayır  ...                             0
#
#   Aktif olarak bir STK üyesi misiniz? Hangi STK'nin Uyesisiniz?  \
# 0                               Hayır                       NaN
# 1                               Hayır                       NaN
#
#   Stk Projesine Katildiniz Mi? Girisimcilikle Ilgili Deneyiminiz Var Mi?  \
# 0                            0                                     Hayır
# ...

# %%
y=eğitimverisi["Degerlendirme Puani"]
x=eğitimverisi[["Burslu ise Burs Yuzdesi","Burslu ise Burs Yuzdesi","Stk Projesine Katildiniz Mi?","Ingilizce Seviyeniz?","id"]]

# %%
standart=StandardScaler()
x=standart.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=21)

# %%
y_pred=model.predict(x_test)
y_test,y_pred
# Out:
# 611/611 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (10630    34
#  11780    42
#  31127     6
#  11811    38
#  14491    18
#           ..
#  30610     9
#  30843    12
#  48580    63
#  65015     4
#  11471    48
#  Name: Degerlendirme Puani, Length: 19538, dtype: int64,
#  array([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], dtype=float32))

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
rmse_LR=np.sqrt(model.score(x_test,y_test))
rmse_LR
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.21664297714799888

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
rmse_LNR=np.sqrt(model.score(x_test,y_test))
rmse_LNR
# Out:
# 0.4031761466295129

# %%
from xgboost import XGBRegressor
model=XGBRegressor()
model.fit(x_train,y_train)
rmse_xgb=np.sqrt(model.score(x_test,y_test))
rmse_xgb
# Out:
# 0.7940139506543292

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(x_train,y_train)
rmse_rf=np.sqrt(model.score(x_test,y_test))
rmse_rf
# Out:
# 0.7064460205424224

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
rmse_dt=np.sqrt(model.score(x_test,y_test))
rmse_dt
# Out:
# 0.5550820388407175

# %%
print(" Lojistik Regresyon modeli tahmini ",rmse_LR)
print(" Liner Regresyon modeli tahmini ",rmse_LNR)
print(" XGBboost modeli tahmini ",rmse_xgb)
print(" Rassal ormanağaçları Regresyonu modeli ",rmse_rf)
print(" Karar ağaçları modeli ",rmse_dt)
# Out:
#  Lojistik Regresyon modeli tahmini  0.21664297714799888
#  Liner Regresyon modeli tahmini  0.4031761466295129
#  XGBboost modeli tahmini  0.7940139506543292
#  Rassal ormanağaçları Regresyonu modeli  0.7064460205424224
#  Karar ağaçları modeli  0.5550820388407175
